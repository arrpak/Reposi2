# %%
f, axes = plt.subplots(figsize=(10,5))

# %%
f, axes = plt.subplots(2,2,figsize=(10,5))

# %%
ax1
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f09ae527fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0995535150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f09954a9d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0995418f90>]], dtype=object)

# %%
axes[0][0].plot(df5['DepDelay'], df5['Distance'])

# %%
axes[0][0].plot(df5['DepDelay'], df5['Distance'],alpha=0.1)

# %%
f, axes = plt.subplots(2,2,figsize=(10,5))
axes[0][0].plot(df5['DepDelay'], df5['Distance'])
axes[0][1].plot(df5['DepDelay'], df5['Distance'],alpha=0.1)

lower_lext = axes[1][0]

# %%
f, axes = plt.subplots(2,2,figsize=(10,5))

subset = df5.sample(10000)

axes[0][0].plot(subset['DepDelay'], subset['Distance'])
axes[0][1].scatter(subset['DepDelay'], subset['Distance'],alpha=0.1)

lower_lext = axes[1][0]

# %%
f, ((ul,ur),(ll,lr)) = plt.subplots(2,2,figsize=(10,5))

subset = df5.sample(10000)

ul.plot(subset['DepDelay'], subset['Distance'])
ur.scatter(subset['DepDelay'], subset['Distance'],alpha=0.1)

ll.scatter(subset['DepDelay'], subset['Distance'])

lr.set_ylim(0,1000)
lr.set_xlim(0,1000)
lr.scatter(subset['DepDelay'], subset['Distance'])

# %%
f2 = plt.figure()
f2.add_subplot(221)
f2.add_subplot(224)

# %%
f.axes
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x7f0984997bd0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f0994b63e90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f098cd99ed0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f098497eb90>]

# %%
##############

# %%
df5 ['DepDateTime'].head(1).map(lambda dt: dt.hour) #no entiendo que meta el lambda
# Out:
# 0    8
# Name: DepDateTime, dtype: int64

# %%
f,ax = plt.subplots()

ax.scatter(df5['Hour'],df5['DepDelay'])

# %%
# plt.boxplot? o shift+tab saca la ayuda

# %%
by_hour = df5.groupby('Hour')['DepDelay']

# %%
for h, g in by_hour:
    print((h))
    print(type(g))
# Out:
# 0
# <class 'pandas.core.series.Series'>
# 1
# <class 'pandas.core.series.Series'>
# 2
# <class 'pandas.core.series.Series'>
# 3
# <class 'pandas.core.series.Series'>
# 4
# <class 'pandas.core.series.Series'>
# 5
# <class 'pandas.core.series.Series'>
# 6
# <class 'pandas.core.series.Series'>
# 7
# <class 'pandas.core.series.Series'>
# 8
# <class 'pandas.core.series.Series'>
# 9
# <class 'pandas.core.series.Series'>
# 10
# <class 'pandas.core.series.Series'>
# 11
# <class 'pandas.core.series.Series'>
# 12
# <class 'pandas.core.series.Series'>
# 13
# <class 'pandas.core.series.Series'>
# 14
# <class 'pandas.core.series.Series'>
# 15
# <class 'pandas.core.series.Series'>
# 16
# <class 'pandas.core.series.Series'>
# 17
# <class 'pandas.core.series.Series'>
# 18
# <class 'pandas.core.series.Series'>
# 19
# <class 'pandas.core.series.Series'>
# 20
# <class 'pandas.core.series.Series'>
# 21
# <class 'pandas.core.series.Series'>
# 22
# <class 'pandas.core.series.Series'>
# 23
# <class 'pandas.core.series.Series'>

# %%
hours = []
groups = []
for h,g in by_hour:
    hours.append(h)
    groups.append(g)

# %%
groups[0][:10]
# Out:
# 152    NaN
# 381    NaN
# 404    NaN
# 699    NaN
# 748    NaN
# 789    NaN
# 827     42
# 923    NaN
# 945    NaN
# 948    146
# Name: DepDelay, dtype: float64

# %%
plt.boxplot(groups)
# Out:
# /home/dsc/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:3403: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)
# {'boxes': [<matplotlib.lines.Line2D at 0x7f098cb11c50>,
#   <matplotlib.lines.Line2D at 0x7f098ccab650>,
#   <matplotlib.lines.Line2D at 0x7f098cb002d0>,
#   <matplotlib.lines.Line2D at 0x7f098cb1ced0>,
#   <matplotlib.lines.Line2D at 0x7f098cb08810>,
#   <matplotlib.lines.Line2D at 0x7f098ce3fc90>,
#   <matplotlib.lines.Line2D at 0x7f098ce10790>,
#   <matplotlib.lines.Line2D at 0x7f098cc4b3d0>,
#   <matplotlib.lines.Line2D at 0x7f098cc42fd0>,
#   <matplotlib.lines.Line2D at 0x7f098cbc5c10>,
#   <matplotlib.lines.Line2D at 0x7f098ce88850>,
#   <matplotlib.lines.Line2D at 0x7f098ceac490>,
#   <matplotlib.lines.Line2D at 0x7f098c9c4ed0>,
#   <matplotlib.lines.Line2D at 0x7f098c9e9cd0>,
#   <matplotlib.lines.Line2D at 0x7f098c98c910>,
#   <matplotlib.lines.Line2D at 0x7f098c9af550>,
#   <matplotlib.lines.Line2D at 0x7f098c955190>,
#   <matplotlib.lines.Line2D at 0x7f098c96dd90>,
#   <matplotlib.lines.Line2D at 0x7f098c9109d0>,
#   <matplotlib.lines.Line2D at 0x7f098c933610>,
#   <matplotlib.lines.Line2D at 0x7f098c8d8250>,
#   <matplotlib.lines.Line2D at 0x7f098c8efe50>,
#   <matplotlib.lines.Line2D at 0x7f098c895a90>,
#   <matplotlib.lines.Line2D at 0x7f098c8b86d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f098cadde90>,
#   <matplotlib.lines.Line2D at 0x7f098cadd3d0>,
#   <matplotlib.lines.Line2D at 0x7f098ca99a90>,
#   <matplotlib.lines.Line2D at 0x7f098caee690>,
#   <matplotlib.lines.Line2D at 0x7f0984a98810>,
#   <matplotlib.lines.Line2D at 0x7f098cb72a10>,
#   <matplotlib.lines.Line2D at 0x7f098cb680d0>,
#   <matplotlib.lines.Line2D at 0x7f098cb5c110>,
#   <matplotlib.lines.Line2D at 0x7f098cd38150>,
#   <matplotlib.lines.Line2D at 0x7f098ca02050>,
#   <matplotlib.lines.Line2D at 0x7f098ce05e10>,
#   <matplotlib.lines.Line2D at 0x7f098ce1b490>,
#   <matplotlib.lines.Line2D at 0x7f098ce35a50>,
#   <matplotlib.lines.Line2D at 0x7f098cc790d0>,
#   <matplotlib.lines.Line2D at 0x7f098cc6f690>,
#   <matplotlib.lines.Line2D at 0x7f098cc6fcd0>,
#   <matplotlib.lines.Line2D at 0x7f098cbd52d0>,
#   <matplotlib.lines.Line2D at 0x7f098cbd5910>,
#   <matplotlib.lines.Line2D at 0x7f098cbdfed0>,
#   <matplotlib.lines.Line2D at 0x7f098cbf0550>,
#   <matplotlib.lines.Line2D at 0x7f098ce94b10>,
#   <matplotlib.lines.Line2D at 0x7f098cea1190>,
#   <matplotlib.lines.Line2D at 0x7f098ceb7750>,
#   <matplotlib.lines.Line2D at 0x7f098ceb7d90>,
#   <matplotlib.lines.Line2D at 0x7f098c9dd390>,
#   <matplotlib.lines.Line2D at 0x7f098c9dd9d0>,
#   <matplotlib.lines.Line2D at 0x7f098c9f4f90>,
#   <matplotlib.lines.Line2D at 0x7f098ca01610>,
#   <matplotlib.lines.Line2D at 0x7f098c999bd0>,
#   <matplotlib.lines.Line2D at 0x7f098c9a4250>,
#   <matplotlib.lines.Line2D at 0x7f098c9bc810>,
#   <matplotlib.lines.Line2D at 0x7f098c9bce50>,
#   <matplotlib.lines.Line2D at 0x7f098c961450>,
#   <matplotlib.lines.Line2D at 0x7f098c961a90>,
#   <matplotlib.lines.Line2D at 0x7f098c904090>,
#   <matplotlib.lines.Line2D at 0x7f098c9046d0>,
#   <matplotlib.lines.Line2D at 0x7f098c91dc90>,
#   <matplotlib.lines.Line2D at 0x7f098c92a310>,
#   <matplotlib.lines.Line2D at 0x7f098c93f8d0>,
#   <matplotlib.lines.Line2D at 0x7f098c93ff10>,
#   <matplotlib.lines.Line2D at 0x7f098c8e5510>,
#   <matplotlib.lines.Line2D at 0x7f098c8e5b50>,
#   <matplotlib.lines.Line2D at 0x7f098c888150>,
#   <matplotlib.lines.Line2D at 0x7f098c888790>,
#   <matplotlib.lines.Line2D at 0x7f098c8a1d50>,
#   <matplotlib.lines.Line2D at 0x7f098c8ac3d0>,
#   <matplotlib.lines.Line2D at 0x7f098c844990>,
#   <matplotlib.lines.Line2D at 0x7f098c844fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f098cc03590>,
#   <matplotlib.lines.Line2D at 0x7f098caee790>,
#   <matplotlib.lines.Line2D at 0x7f098cb1c150>,
#   <matplotlib.lines.Line2D at 0x7f098cb086d0>,
#   <matplotlib.lines.Line2D at 0x7f09845bae90>,
#   <matplotlib.lines.Line2D at 0x7f098ce10150>,
#   <matplotlib.lines.Line2D at 0x7f098cc79d50>,
#   <matplotlib.lines.Line2D at 0x7f098cc42990>,
#   <matplotlib.lines.Line2D at 0x7f098cbc55d0>,
#   <matplotlib.lines.Line2D at 0x7f098ce88210>,
#   <matplotlib.lines.Line2D at 0x7f098cea1e10>,
#   <matplotlib.lines.Line2D at 0x7f098c9c4a50>,
#   <matplotlib.lines.Line2D at 0x7f098c9e9690>,
#   <matplotlib.lines.Line2D at 0x7f098c98c2d0>,
#   <matplotlib.lines.Line2D at 0x7f098c9a4ed0>,
#   <matplotlib.lines.Line2D at 0x7f098c948b10>,
#   <matplotlib.lines.Line2D at 0x7f098c96d750>,
#   <matplotlib.lines.Line2D at 0x7f098c910390>,
#   <matplotlib.lines.Line2D at 0x7f098c92af90>,
#   <matplotlib.lines.Line2D at 0x7f098c8ccbd0>,
#   <matplotlib.lines.Line2D at 0x7f098c8ef810>,
#   <matplotlib.lines.Line2D at 0x7f098c895450>,
#   <matplotlib.lines.Line2D at 0x7f098c8b8090>,
#   <matplotlib.lines.Line2D at 0x7f098c850c90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f098ca08e50>,
#   <matplotlib.lines.Line2D at 0x7f098caee310>,
#   <matplotlib.lines.Line2D at 0x7f098cb72850>,
#   <matplotlib.lines.Line2D at 0x7f098cb5ccd0>,
#   <matplotlib.lines.Line2D at 0x7f098cd2cdd0>,
#   <matplotlib.lines.Line2D at 0x7f098ce1bad0>,
#   <matplotlib.lines.Line2D at 0x7f098cc79710>,
#   <matplotlib.lines.Line2D at 0x7f098cc42350>,
#   <matplotlib.lines.Line2D at 0x7f098cbd5f50>,
#   <matplotlib.lines.Line2D at 0x7f098cbf0b90>,
#   <matplotlib.lines.Line2D at 0x7f098cea17d0>,
#   <matplotlib.lines.Line2D at 0x7f098c9c4410>,
#   <matplotlib.lines.Line2D at 0x7f098c9e9050>,
#   <matplotlib.lines.Line2D at 0x7f098ca01c50>,
#   <matplotlib.lines.Line2D at 0x7f098c9a4890>,
#   <matplotlib.lines.Line2D at 0x7f098c9484d0>,
#   <matplotlib.lines.Line2D at 0x7f098c96d110>,
#   <matplotlib.lines.Line2D at 0x7f098c904d10>,
#   <matplotlib.lines.Line2D at 0x7f098c92a950>,
#   <matplotlib.lines.Line2D at 0x7f098c8cc590>,
#   <matplotlib.lines.Line2D at 0x7f098c8ef1d0>,
#   <matplotlib.lines.Line2D at 0x7f098c888dd0>,
#   <matplotlib.lines.Line2D at 0x7f098c8aca10>,
#   <matplotlib.lines.Line2D at 0x7f098c850650>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f098cb11950>,
#   <matplotlib.lines.Line2D at 0x7f098cb11610>,
#   <matplotlib.lines.Line2D at 0x7f098ca5ee10>,
#   <matplotlib.lines.Line2D at 0x7f098ca99190>,
#   <matplotlib.lines.Line2D at 0x7f098cb009d0>,
#   <matplotlib.lines.Line2D at 0x7f098cab6410>,
#   <matplotlib.lines.Line2D at 0x7f098cb685d0>,
#   <matplotlib.lines.Line2D at 0x7f098cb68fd0>,
#   <matplotlib.lines.Line2D at 0x7f098cd38f90>,
#   <matplotlib.lines.Line2D at 0x7f098cd38b10>,
#   <matplotlib.lines.Line2D at 0x7f098ce05190>,
#   <matplotlib.lines.Line2D at 0x7f098ce057d0>,
#   <matplotlib.lines.Line2D at 0x7f098ce10d90>,
#   <matplotlib.lines.Line2D at 0x7f098ce35410>,
#   <matplotlib.lines.Line2D at 0x7f098cc4b9d0>,
#   <matplotlib.lines.Line2D at 0x7f098cc6f050>,
#   <matplotlib.lines.Line2D at 0x7f098cc00610>,
#   <matplotlib.lines.Line2D at 0x7f098cc00c50>,
#   <matplotlib.lines.Line2D at 0x7f098cbdf250>,
#   <matplotlib.lines.Line2D at 0x7f098cbdf890>,
#   <matplotlib.lines.Line2D at 0x7f098ce88e50>,
#   <matplotlib.lines.Line2D at 0x7f098ce944d0>,
#   <matplotlib.lines.Line2D at 0x7f098ceaca90>,
#   <matplotlib.lines.Line2D at 0x7f098ceb7110>,
#   <matplotlib.lines.Line2D at 0x7f098c9cf6d0>,
#   <matplotlib.lines.Line2D at 0x7f098c9cfd10>,
#   <matplotlib.lines.Line2D at 0x7f098c9f4310>,
#   <matplotlib.lines.Line2D at 0x7f098c9f4950>,
#   <matplotlib.lines.Line2D at 0x7f098c98cf10>,
#   <matplotlib.lines.Line2D at 0x7f098c999590>,
#   <matplotlib.lines.Line2D at 0x7f098c9afb50>,
#   <matplotlib.lines.Line2D at 0x7f098c9bc1d0>,
#   <matplotlib.lines.Line2D at 0x7f098c955790>,
#   <matplotlib.lines.Line2D at 0x7f098c955dd0>,
#   <matplotlib.lines.Line2D at 0x7f098c9793d0>,
#   <matplotlib.lines.Line2D at 0x7f098c979a10>,
#   <matplotlib.lines.Line2D at 0x7f098c910fd0>,
#   <matplotlib.lines.Line2D at 0x7f098c91d650>,
#   <matplotlib.lines.Line2D at 0x7f098c933c10>,
#   <matplotlib.lines.Line2D at 0x7f098c93f290>,
#   <matplotlib.lines.Line2D at 0x7f098c8d8850>,
#   <matplotlib.lines.Line2D at 0x7f098c8d8e90>,
#   <matplotlib.lines.Line2D at 0x7f098c8fb490>,
#   <matplotlib.lines.Line2D at 0x7f098c8fbad0>,
#   <matplotlib.lines.Line2D at 0x7f098c8a10d0>,
#   <matplotlib.lines.Line2D at 0x7f098c8a1710>,
#   <matplotlib.lines.Line2D at 0x7f098c8b8cd0>,
#   <matplotlib.lines.Line2D at 0x7f098c844350>]}

# %%
f, ax = plt.subplots(figsize=(10,5))
ax.set_ylim(-200,1000)
labels = plt.setp(ax,xticklabels=hours)
bp = plt.boxplot(groups)

# %%
f, ax = plt.subplots(figsize=(8,4))
ax.set_ylim(-200,300)
labels = plt.setp(ax,xticklabels=hours[8:12])
bp = plt.boxplot(groups[8:12])
