# %%
import pandas as pd
import os 
import zipfile

# %%
# !ls /home/dsc/Data/opentraveldata/
# Out:
# create_table_optd_aircraft.sql	  optd_airlines.csv
# create_table_optd_airlines.sql	  optd_por_public.csv
# create_table_optd_por_public.sql  optd_por_public_with_errors.csv
# Finn.txt			  optd_por_public_with_errors_null2.csv
# grep2				  optd_por_public_with_errors_null.csv
# grepfile2			  optd_por_public_without_errors.csv
# grepfile.gz			  ref_airline_nb_of_flights.csv
# optd_aircraft.csv		  tmp

# %%
path_to_csvs = '/home/dsc/Data/opentraveldata/'

# %%
# !ls {path_to_csvs}
# Out:
# create_table_optd_aircraft.sql	  optd_airlines.csv
# create_table_optd_airlines.sql	  optd_por_public.csv
# create_table_optd_por_public.sql  optd_por_public_with_errors.csv
# Finn.txt			  optd_por_public_with_errors_null2.csv
# grep2				  optd_por_public_with_errors_null.csv
# grepfile2			  optd_por_public_without_errors.csv
# grepfile.gz			  ref_airline_nb_of_flights.csv
# optd_aircraft.csv		  tmp

# %%
path_vm = '/home/dsc/Data/opentraveldata'

# %%
csvs = !ls {path_to_csvs}

# %%
csvs
# Out:
# ['create_table_optd_aircraft.sql',
#  'create_table_optd_airlines.sql',
#  'create_table_optd_por_public.sql',
#  'Finn.txt',
#  'grep2',
#  'grepfile2',
#  'grepfile.gz',
#  'optd_aircraft.csv',
#  'optd_airlines.csv',
#  'optd_por_public.csv',
#  'optd_por_public_with_errors.csv',
#  'optd_por_public_with_errors_null2.csv',
#  'optd_por_public_with_errors_null.csv',
#  'optd_por_public_without_errors.csv',
#  'ref_airline_nb_of_flights.csv',
#  'tmp']

# %%
# !head {path_to_csvs + '/' + csvs[0]}
# Out:
# CREATE TABLE optd_aircraft (
# 	iata_code VARCHAR(3) NOT NULL,
# 	manufacturer VARCHAR(30),
# 	model VARCHAR(45) NOT NULL,
# 	iata_group VARCHAR(4),
# 	iata_category VARCHAR(10),
# 	icao_code VARCHAR(4),
# 	nb_engines INTEGER,
# 	aircraft_type VARCHAR(4)
# );

# %%
path_to_aircraft = path_to_csvs + '/' + csvs[0]

# %%
df_ac = pd.read_csv(path_to_aircraft, sep='^')

# %%
df_ac.ix[5]
# Out:
# CREATE TABLE optd_aircraft (    \ticao_code VARCHAR(4),
# Name: 5, dtype: object

# %%
df_ac = pd.read_csv(path_to_aircraft, sep='^')

# %%
len(df_ac)
# Out:
# 9

# %%
df_ac.to_excel('ac.xls')

# %%
# !pwd
# Out:
# /home/dani/dev/master-data-science/07_pandas_for_data_science

# %%
import sqlite3

# %%
conn = sqlite3.connect('example.db')

# %%
df_ac.to_sql('aircraft', conn, if_exists='replace')

# %%
df_ac.to_json(orient='records')
# Out:
# '[{"iata_code":"100","manufacturer":"Fokker","model":"100","iata_group":"100","iata_category":"2J","icao_code":"F100","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"141","manufacturer":"BAe","model":"146-100","iata_group":"146","iata_category":"4J","icao_code":"B461","nb_engines":4.0,"aircraft_type":"J"},{"iata_code":"142","manufacturer":"BAe","model":"BAE Systems 146-200 Passenger","iata_group":"146","iata_category":"4J","icao_code":"B462","nb_engines":4.0,"aircraft_type":"J"},{"iata_code":"143","manufacturer":"BAe","model":"146-300","iata_group":"146","iata_category":"4J","icao_code":"B463","nb_engines":4.0,"aircraft_type":"J"},{"iata_code":"146","manufacturer":"BAe","model":"146","iata_group":null,"iata_category":null,"icao_code":null,"nb_engines":null,"aircraft_type":null},{"iata_code":"14F","manufacturer":"BAe","model":"146 Freighter (-100\\/200\\/300QT & QC)","iata_group":null,"iata_category":null,"icao_code":null,"nb_engines":null,"aircraft_type":null},{"iata_code":"14X","manufacturer":"BAe","model":"146 Freighter (-100QT & QC)","iata_group":"14F","iata_category":"4J","icao_code":"B461","nb_engines":4.0,"aircraft_type":"J"},{"iata_code":"14Y","manufacturer":"BAe","model":"146 Freighter (-200QT & QC)","iata_group":"14F","iata_category":"4J","icao_code":"B462","nb_engines":4.0,"aircraft_type":"J"},{"iata_code":"14Z","manufacturer":"BAe","model":"146 Freighter (-300QT & QC)","iata_group":"14F","iata_category":"4J","icao_code":"B463","nb_engines":4.0,"aircraft_type":"J"},{"iata_code":"19D","manufacturer":"Airbus","model":"A319","iata_group":null,"iata_category":null,"icao_code":null,"nb_engines":null,"aircraft_type":null},{"iata_code":"310","manufacturer":"Airbus","model":"A310","iata_group":null,"iata_category":null,"icao_code":null,"nb_engines":null,"aircraft_type":null},{"iata_code":"312","manufacturer":"Airbus","model":"A310-200","iata_group":"310","iata_category":"2J","icao_code":"A310","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"313","manufacturer":"Airbus","model":"A310-300","iata_group":"310","iata_category":"2J","icao_code":"A310","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"318","manufacturer":"Airbus","model":"A318","iata_group":"32S","iata_category":"2J","icao_code":"A318","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"319","manufacturer":"Airbus","model":"A319","iata_group":"32S","iata_category":"2J","icao_code":"A319","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"31F","manufacturer":"Airbus","model":"A310F","iata_group":null,"iata_category":null,"icao_code":null,"nb_engines":null,"aircraft_type":null},{"iata_code":"31W","manufacturer":"Airbus","model":"A319 (Sharklets)","iata_group":null,"iata_category":null,"icao_code":null,"nb_engines":null,"aircraft_type":null},{"iata_code":"31X","manufacturer":"Airbus","model":"A310-200F","iata_group":"31F","iata_category":"2J","icao_code":"A310","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"31Y","manufacturer":"Airbus","model":"A310-300F","iata_group":"31F","iata_category":"2J","icao_code":"A310","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"320","manufacturer":"Airbus","model":"A320-100\\/200","iata_group":"32S","iata_category":"2J","icao_code":"A320","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"321","manufacturer":"Airbus","model":"A321-100\\/200","iata_group":"32S","iata_category":"2J","icao_code":"A321","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"32A","manufacturer":"Airbus","model":"A320 (sharklets)","iata_group":"32S","iata_category":"2J","icao_code":"A320","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"32B","manufacturer":"Airbus","model":"A321 (sharklets)","iata_group":"32S","iata_category":"2J","icao_code":"A321","nb_engines":2.0,"aircraft_type":"J"},{"iata_code":"32C","manufacturer":"Airbus","model":"A318 (sharklets)","iata_group":null,"iata_category":null,"icao_code":null,"nb_engines":null,"aircraft_type":null},{"iata_code":"32D","manufacturer":"Airbus","model":"A319 (sharklets)","iata_group":null," ...

# %%
df2 = pd.read_excel('ac.xls')

# %%
df2.head()
# Out:
#   iata_code manufacturer                          model iata_group  \
# 0       100       Fokker                            100        100
# 1       141          BAe                        146-100        146
# 2       142          BAe  BAE Systems 146-200 Passenger        146
# 3       143          BAe                        146-300        146
# 4       146          BAe                            146        NaN
#
#   iata_category icao_code  nb_engines aircraft_type
# 0            2J      F100           2             J
# 1            4J      B461           4             J
# 2            4J      B462           4             J
# 3            4J      B463           4             J
# 4           NaN       NaN         NaN           NaN

# %%
df3 = pd.read_sql_query('SELECT * from aircraft', conn)

# %%
# Out:
#   iata_code manufacturer                          model iata_group  \
# 0       100       Fokker                            100        100
# 1       141          BAe                        146-100        146
# 2       142          BAe  BAE Systems 146-200 Passenger        146
# 3       143          BAe                        146-300        146
# 4       146          BAe                            146        NaN
#
#   iata_category icao_code  nb_engines aircraft_type
# 0            2J      F100           2             J
# 1            4J      B461           4             J
# 2            4J      B462           4             J
# 3            4J      B463           4             J
# 4           NaN       NaN         NaN           NaN

# %% [markdown]
# # Group by

# %%
df_ac.head()index_col
# Out:
#   iata_code manufacturer                          model iata_group  \
# 0       100       Fokker                            100        100
# 1       141          BAe                        146-100        146
# 2       142          BAe  BAE Systems 146-200 Passenger        146
# 3       143          BAe                        146-300        146
# 4       146          BAe                            146        NaN
#
#   iata_category icao_code  nb_engines aircraft_type
# 0            2J      F100           2             J
# 1            4J      B461           4             J
# 2            4J      B462           4             J
# 3            4J      B463           4             J
# 4           NaN       NaN         NaN           NaN

# %%
gb = df_ac.groupby(df_ac['manufacturer'])

# %%
gb

# %%
gb['nb_engines']

# %%
gb['nb_engines'].mean()
# Out:
# manufacturer
# ATR                               2.000000
# Aerospatiale / SNIAS              2.000000
# Agusta / AgustaWestland                NaN
# AgustaWestland                    2.000000
# Airbus                            2.413793
# Aircraft Industries (LET)         2.000000
# Airtech                           2.000000
# Antonov                           3.200000
# Antonow / Antonov                 2.444444
# Ayres                                  NaN
# BAC                               2.000000
# BAe                               3.200000
# Beechcraft                        1.875000
# Bell Helicopter                        NaN
# Boeing                            2.698630
# Bombardier                        2.000000
# Britten Norman                    2.500000
# CASA                              2.000000
# Canadair                          2.000000
# Cessna                            1.857143
# Comac                             2.000000
# Convair                           2.000000
# Curtiss                           2.000000
# DAHER-SOCATA                      1.000000
# Dassault                          2.500000
# De Havilland                      3.000000
# De Havilland Canada               1.666667
# De Havilland Canada-Bombardier    2.000000
# De Havilland-Bombardier                NaN
# Diamond Aircraft                  2.000000
#                                     ...
# Helio                             1.000000
# IAI                               2.000000
# Ilyushin                          3.714286
# Junkers                           3.000000
# LET                               2.000000
# Learjet                           2.000000
# Lockheed                          3.500000
# MBB                                    NaN
# MD Helicopters                         NaN
# McDonnell Douglas                 2.470588
# Mil                                    NaN
# Mitsubishi                        2.000000
# NAMC                              2.000000
# Nord / SNCAN                           NaN
# Partenavia                        2.000000
# Piaggio Aero                      2.000000
# Pilatus                           1.000000
# Piper                             1.666667
# Rockwell                          2.000000
# Saab                              2.000000
# Shaanxi                           4.000000
# Shorts                            2.000000
# Sikorsky                               NaN
# Sud-Est                                NaN
# Sukhoi                            2.000000
# Surface Equipment                      NaN
# Tupolev                           2.200000
# Vickers                                NaN
# Xian                              2.000000
# Yakovlev / Jakovlev               3.000000
# Name: nb_engines, dtype: float64

# %%
gb_2 = df_ac.groupby(['manufacturer','iata_group'])

# %%
gb_2

# %%
gb_2['nb_engines'].mean()
# Out:
# manufacturer               iata_group
# ATR                        ATF           2.000000
#                            ATR           2.000000
#                            ATZ           2.000000
# Aerospatiale / SNIAS       NDC           2.000000
# Agusta / AgustaWestland    AGH                NaN
# AgustaWestland             AWH           2.000000
# Airbus                     310           2.000000
#                            31F           2.000000
#                            32F           2.000000
#                            32S           2.000000
#                            32X           2.000000
#                            330           2.000000
#                            33F           2.000000
#                            340           4.000000
#                            350           2.000000
#                            380           4.000000
#                            38F           4.000000
#                            AB3           2.000000
#                            ABF           2.000000
# Aircraft Industries (LET)  L4F           2.000000
# Airtech                    CS5           2.000000
# Antonov                    A22           4.000000
#                            A38           2.000000
#                            A58           2.000000
#                            A5F           6.000000
#                            A81           2.000000
# Antonow / Antonov          A28           2.000000
#                            A40           2.000000
#                            A4F           4.000000
#                            AN4           2.000000
#                                            ...
# Partenavia                 PN6           2.000000
# Piaggio Aero               P18           2.000000
# Pilatus                    PL2           1.000000
#                            PL6           1.000000
# Piper                      PAG           1.666667
# Rockwell                   ACD           2.000000
# Saab                       S20           2.000000
#                            SF3           2.000000
#                            SFF           2.000000
# Shaanxi                    SY8           4.000000
# Shorts                     SH3           2.000000
#                            SH6           2.000000
#                            SHS           2.000000
# Sikorsky                   S58                NaN
#                            S61                NaN
#                            S76                NaN
# Sukhoi                     SU1           2.000000
# Surface Equipment          BUS                NaN
#                            LCH                NaN
#                            LMO                NaN
#                            TRN                NaN
# Tupolev                    T20           2.000000
#                            T2F           2.000000
#                            T34           2.000000
#                            TU3           2.000000
#                            TU5           3.000000
# Xian                       MA6           2.000000
#                            YN7           2.000000
# Yakovlev / Jakovlev        YK2           3.000000
#                            YK4           3.000000
# Name: nb_engines, dtype: float64

# %%
type(gb_2['nb_engines'].count())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Iterating over groups

# %%
for name, group in df_ac.groupby('manufacturer'):
    print name
    print group[['nb_engines','icao_code']]
# Out:
# ATR
#      nb_engines icao_code
# 173           2      AT43
# 174           2      AT45
# 175           2      AT72
# 176           2      AT44
# 177           2      AT72
# 179         NaN       NaN
# 180           2         *
# Aerospatiale / SNIAS
#      nb_engines icao_code
# 411           2      S601
# 435         NaN       NaN
# Agusta / AgustaWestland
#      nb_engines icao_code
# 159         NaN      A109
# AgustaWestland
#      nb_engines icao_code
# 181           2      A139
# Airbus
#      nb_engines icao_code
# 9           NaN       NaN
# 10          NaN       NaN
# 11            2      A310
# 12            2      A310
# 13            2      A318
# 14            2      A319
# 15          NaN       NaN
# 16          NaN       NaN
# 17            2      A310
# 18            2      A310
# 19            2      A320
# 20            2      A321
# 21            2      A320
# 22            2      A321
# 23          NaN       NaN
# 24          NaN       NaN
# 25            2      A320
# 26            2      A321
# 27          NaN       NaN
# 28            2      A332
# 29            2      A333
# 30          NaN       NaN
# 31            2      A332
# 32          NaN       NaN
# 33            4      A342
# 34            4      A343
# 35            4      A345
# 36            4      A346
# 37          NaN       NaN
# 38            2      ZZZZ
# 39            2      ZZZZ
# 40            2      ZZZZ
# 41          NaN       NaN
# 42            4      A388
# 43            4      A388
# 147         NaN       NaN
# 148         NaN       NaN
# 149           2      A30B
# 150           2      A306
# 151           2      A3ST
# 152         NaN       NaN
# 153         NaN       NaN
# 154           2      A30B
# 155           2      A306
# Aircraft Industries (LET)
#      nb_engines icao_code
# 381           2      L410
# Airtech
#      nb_engines icao_code
# 237           2      CN35
# Antonov
#      nb_engines icao_code
# 136           4      AN22
# 141           2      AN38
# 144           2      ZZZZ
# 145           6      A225
# 146           2      A148
# 162         NaN       NaN
# Antonow / Antonov
#      nb_engines icao_code
# 137           2      AN26
# 138           2      AN28
# 139           2      AN30
# 140           2      AN32
# 142           2      A140
# 143           4      A124
# 163           2      AN24
# 164         NaN       NaN
# 165           2      AN72
# 166           4      AN12
# Ayres
#      nb_engines icao_code
# 160         NaN       NaN
# BAC
#      nb_engines icao_code
# 182         NaN       NaN
# 183           2      BA11
# 184           2      BA11
# 185           2      BA11
# 186           2      BA11
# BAe
#      nb_engines icao_code
# 1             4      B461
# 2             4      B462
# 3             4      B463
# 4           NaN       NaN
# 5           NaN       NaN
# 6             4      B461
# 7             4      B462
# 8             4      B463
# 167           2      ZZZZ
# 169           4      RJ1H
# 170           4      RJ70
# 171           4      RJ85
# 172         NaN       NaN
# 178           2       ATP
# 359           2      A748
# 371           2      JS31
# 372           2      JS32
# 373           2      JS41
# 374         NaN       NaN
# Beechcraft
#      nb_engines icao_code
# 188         NaN       NaN
# 189           2         *
# 190           2      BE40
# 191           2      BE99
# 192         NaN       NaN
# 193           2      B190
# 194           2      B190
# 195           1         *
# 196           2      B190
# 197           2         *
# Bell Helicopter
#      nb_engines icao_code
# 198         NaN         *
# Boeing
#      nb_engines icao_code
# 44            4      B703
# 45          NaN       NaN
# 46            4      B703
# 47            4      B703
# 48            2      B712
# 49            3      B721
# 50            3      B722
# 51          NaN       NaN
# 52          NaN       NaN
# 53            3      B721
# 54            3      B722
# 55          NaN       NaN
# 56          NaN       NaN
# 57          NaN       NaN
# 58            3      B722
# 59            3      B721
# 60            3      B722
# 61            2      B731
# 62            2      B732
# 63            2      B733
# 64            2      B734
# 65            2      B735
# 66            2      B736
# 67          NaN       NaN
# 68            2      B738
# 69            2      B739
# 70          NaN       NaN
# 71            2      B733
# 72            2      B735
# 73          NaN       NaN
# ..          ...       ...
# 107           4      B742
# 108           4      B744
# 109           2      B752
# 110           2      B753
# 111         NaN       NaN
# 112           2      B752
# 113           2      B752
# 114           2      B753
# 115           2      B752
# 116           2      B762
# 117           2      B763
# 118           2      B764
# 119         NaN       NaN
# 120         NaN       NaN
# 121           2      B763
# 122           2      B763
# 123           2      B762
# 124           2      B763
# 125           2      B77L
# 126           2      B773
# 127         NaN       NaN
# 128         NaN       NaN
# 129           2      B772
# 130           2      B77W
# 131           2      B772
# 132           2      B783
# 133         NaN       NaN
# 134           2      B788
# 135           2      B789
# 187           4      B720
#
# [93 rows x 2 columns]
# Bombardier
#      nb_engines icao_code
# 206           2      GLEX
# 215           2      CL30
# 234           2      ZZZZ
# 236           2      ZZZZ
# Britten Norman
#      nb_engines icao_code
# 199           2      BN2P
# 200           3      TRIS
# CASA
#      nb_engines icao_code
# 235           2      C212
# Canadair
#      nb_engines icao_code
# 204         NaN       NaN
# 205           2      CL60
# 216         NaN       NaN
# 225           2      CRJ1
# 226           2      CRJ2
# 227           2      CRJ7
# 228           2      CRJ9
# 229           2      CRJ9
# 230           2      ZZZZ
# 231         NaN       NaN
# 232           2      CRJX
# Cessna
#      nb_engines icao_code
# 208           2         *
# 209           2         *
# 210           2         *
# 211           2         *
# 212           2         *
# 213           2         *
# 214           2      C510
# 217           1         *
# 218           2         *
# 219           2      C750
# 220         NaN       NaN
# 221           1         *
# 222           2         *
# 223           2         *
# 224           2         *
# Comac
#      nb_engines icao_code
# 203           2      AJ27
# Convair
#      nb_engines icao_code
# 238           2      CVLP
# 239           2      CVLP
# 240           2      CVLT
# 241         NaN       NaN
# 242         NaN       NaN
# 243         NaN       NaN
# 244           2      CVLP
# 245           2      CVLP
# 246           2      CVLT
# Curtiss
#      nb_engines icao_code
# 247           2       C46
# DAHER-SOCATA
#      nb_engines icao_code
# 445           1      TBM7
# Dassault
#      nb_engines icao_code
# 161         NaN       NaN
# 256           2      F2TH
# 258           2      F2TH
# 284           3      F900
# 291           2      FA10
# 292           2      FA20
# 293         NaN       NaN
# 294           3      FA50
# 295           3      FA7X
# 296           3      F900
# 297         NaN       NaN
# De Havilland
#      nb_engines icao_code
# 306           2      DOVE
# 308           4      HERN
# De Havilland Canada
#      nb_engines icao_code
# 302           4      DHC7
# 304         NaN       NaN
# 305           2      DHC4
# 309           1      DH3T
# 310         NaN       NaN
# 311           1      DHC2
# 312           1      DH2T
# 313           1      DHC3
# 314         NaN        2T
# De Havilland Canada-Bombardier
#      nb_engines icao_code
# 262           2      DH8D
# 298           2      DH8A
# 299           2      DH8B
# 300           2      DH8C
# 301           2      DH8D
# 303         NaN       NaN
# De Havilland-Bombardier
#      nb_engines icao_code
# 307         NaN      0000
# Diamond Aircraft
#      nb_engines icao_code
# 261           2      DA42
# Dornier
#      nb_engines icao_code
# 257           2      D228
# 259           2      D328
# 340         NaN       NaN
# 341         NaN       NaN
# 342           2      J328
# Douglas
#      nb_engines icao_code
# 260           2       DC3
# 263           4       DC6
# 264         NaN       NaN
# 265         NaN       NaN
# 266         NaN       NaN
# 267         NaN       NaN
# 268         NaN       NaN
# 269         NaN       NaN
# 270           4      DC86
# 271           4      DC86
# 272           4      DC87
# 273           4      DC85
# 274           4      DC86
# 275           4      DC87
# 276           2      DC91
# 277           2      DC92
# 278           2      DC93
# 279           2      DC94
# 280           2      DC95
# 281           2      DC93
# 282           2      DC94
# 283         NaN       NaN
# 285           2      DC91
# 286           2       DC3
# 287           4       DC4
# 288           4       DC6
# 289         NaN       NaN
# 290         NaN       NaN
# Eclipse
#      nb_engines icao_code
# 319           2      EA50
# Embraer
#      nb_engines icao_code
# 315           2      E170
# 316           2      E170
# 317           2      E190
# 318           2      E190
# 321           2      E120
# 322           2      E110
# 323         NaN       NaN
# 324           2      E50P
# 325           2      E55P
# 326           2      E135
# 327           2      E145
# 328           2      E135
# 329         NaN       NaN
# Eurocopter
#      nb_engines icao_code
# 168         NaN         *
# 320         NaN      EC30
# 412         NaN         *
# 413         NaN         *
# Fairchild-Hiller
#      nb_engines icao_code
# 339           2       F27
# Fairchild-Swearingen
#      nb_engines icao_code
# 439           2         *
# 440           2         *
# Fokker
#      nb_engines icao_code
# 0             2      F100
# 330           2       F28
# 331           2       F28
# 332           2       F28
# 333           2       F28
# 334           2       F27
# 335         NaN       NaN
# 336           2       F50
# 337           2       F50
# 338           2       F70
# GAF
#      nb_engines icao_code
# 207           2      NOMA
# GippsAero
#      nb_engines icao_code
# 343           1       GA8
# Grumman
#      nb_engines icao_code
# 347           2       G21
# Gulfstream
#      nb_engines icao_code
# 344           2      G150
# 345           2      GALX
# 346           2      G250
# 348           2         *
# 349           2      G73T
# 350           2      G159
# HAMC / Harbin
#      nb_engines icao_code
# 454           2       Y12
# Hawker-Beechcraft
#      nb_engines icao_code
# 351           2      ZZZZ
# 352           2      H25C
# 353           2      HA4T
# 355           2      H25B
# 356           2      H25B
# 422           2      PRM1
# Hawker-Siddeley
#      nb_engines icao_code
# 354           2      H25B
# Helio
#      nb_engines icao_code
# 357           1      COUR
# IAI
#      nb_engines icao_code
# 451           2      WW24
# Ilyushin
#      nb_engines icao_code
# 360           2      I114
# 361         NaN       NaN
# 362           4      IL96
# 363         NaN       NaN
# 364         NaN       NaN
# 365         NaN       NaN
# 366           4      IL62
# 367           4      IL76
# 368           4      IL18
# 369           4      IL96
# 370           4      IL86
# Junkers
#      nb_engines icao_code
# 375           3      JU52
# LET
#      nb_engines icao_code
# 382           2      L410
# Learjet
#      nb_engines icao_code
# 390           2         *
# Lockheed
#      nb_engines icao_code
# 376         NaN       NaN
# 377           3      L101
# 378           3      L101
# 379           3      L101
# 380         NaN       NaN
# 386           4      L188
# 387           4      L188
# 388           4      C130
# 389         NaN       NaN
# MBB
#      nb_engines icao_code
# 406         NaN      B105
# MD Helicopters
#      nb_engines icao_code
# 407         NaN      EXPL
# McDonnell Douglas
#      nb_engines icao_code
# 248         NaN       NaN
# 249           3      DC10
# 250         NaN       NaN
# 251           3      DC10
# 252         NaN       NaN
# 253           3      DC10
# 254           3      DC10
# 255           3      DC10
# 391           3      MD11
# 392           3      MD11
# 393           3      MD11
# 394           2      MD82
# 395           2      MD83
# 396         NaN       NaN
# 397           2      MD81
# 398           2      MD82
# 399           2      MD83
# 400           2      MD87
# 401           2      MD88
# 402           2      MD88
# 403           2      MD90
# 404         NaN       NaN
# Mil
#      nb_engines icao_code
# 408         NaN       MI8
# Mitsubishi
#      nb_engines icao_code
# 409           2       MU2
# NAMC
#      nb_engines icao_code
# 456           2      YS11
# Nord / SNCAN
#      nb_engines icao_code
# 410         NaN       NaN
# Partenavia
#      nb_engines icao_code
# 421           2       P68
# Piaggio Aero
#      nb_engines icao_code
# 414           2      P180
# Pilatus
#      nb_engines icao_code
# 419           1      PC12
# 420           1      PC6T
# Piper
#      nb_engines icao_code
# 415           1         *
# 416           2         *
# 417         NaN       NaN
# 418           2         *
# Rockwell
#      nb_engines icao_code
# 156         NaN       NaN
# 157           2         *
# 158           2         *
# Saab
#      nb_engines icao_code
# 424           2      SB20
# 428           2      SF34
# 429           2      SF34
# 430           2      SF34
# Shaanxi
#      nb_engines icao_code
# 441           4      AN12
# Shorts
#      nb_engines icao_code
# 431           2      SH33
# 432           2      SH36
# 433         NaN       NaN
# 434           2       SC7
# Sikorsky
#      nb_engines icao_code
# 425         NaN      S58T
# 426         NaN       S61
# 427         NaN       S76
# Sud-Est
#      nb_engines icao_code
# 233         NaN       NaN
# Sukhoi
#      nb_engines icao_code
# 436         NaN       NaN
# 437           2      ZZZZ
# 438           2      SU95
# Surface Equipment
#      nb_engines icao_code
# 202         NaN      0000
# 383         NaN      0000
# 385         NaN      0000
# 446         NaN      0000
# Tupolev
#      nb_engines icao_code
# 442           2      T204
# 443           2      T204
# 444           2      T334
# 447           2      T134
# 448           3      T154
# Vickers
#      nb_engines icao_code
# 449         NaN       NaN
# 450         NaN       NaN
# Xian
#      nb_engines icao_code
# 405           2      AN24
# 455           2      AN24
# Yakovlev / Jakovlev
#      nb_engines icao_code
# 452           3      YK42
# 453           3      YK40

# %%
for (mf, iata), group in df_ac.groupby(['manufacturer', 'iata_code']):
    print mf
    print iata
    print group[['nb_engines','icao_code']]
# Out:
# ATR
# AT4
#      nb_engines icao_code
# 173           2      AT43
# ATR
# AT5
#      nb_engines icao_code
# 174           2      AT45
# ATR
# AT7
#      nb_engines icao_code
# 175           2      AT72
# ATR
# ATD
#      nb_engines icao_code
# 176           2      AT44
# ATR
# ATF
#      nb_engines icao_code
# 177           2      AT72
# ATR
# ATR
#      nb_engines icao_code
# 179         NaN       NaN
# ATR
# ATZ
#      nb_engines icao_code
# 180           2         *
# Aerospatiale / SNIAS
# NDC
#      nb_engines icao_code
# 411           2      S601
# Aerospatiale / SNIAS
# SSC
#      nb_engines icao_code
# 435         NaN       NaN
# Agusta / AgustaWestland
# AGH
#      nb_engines icao_code
# 159         NaN      A109
# AgustaWestland
# AWH
#      nb_engines icao_code
# 181           2      A139
# Airbus
# 19D
#    nb_engines icao_code
# 9         NaN       NaN
# Airbus
# 310
#     nb_engines icao_code
# 10         NaN       NaN
# Airbus
# 312
#     nb_engines icao_code
# 11           2      A310
# Airbus
# 313
#     nb_engines icao_code
# 12           2      A310
# Airbus
# 318
#     nb_engines icao_code
# 13           2      A318
# Airbus
# 319
#     nb_engines icao_code
# 14           2      A319
# Airbus
# 31F
#     nb_engines icao_code
# 15         NaN       NaN
# Airbus
# 31W
#     nb_engines icao_code
# 16         NaN       NaN
# Airbus
# 31X
#     nb_engines icao_code
# 17           2      A310
# Airbus
# 31Y
#     nb_engines icao_code
# 18           2      A310
# Airbus
# 320
#     nb_engines icao_code
# 19           2      A320
# Airbus
# 321
#     nb_engines icao_code
# 20           2      A321
# Airbus
# 32A
#     nb_engines icao_code
# 21           2      A320
# Airbus
# 32B
#     nb_engines icao_code
# 22           2      A321
# Airbus
# 32C
#     nb_engines icao_code
# 23         NaN       NaN
# Airbus
# 32D
#     nb_engines icao_code
# 24         NaN       NaN
# Airbus
# 32F
#     nb_engines icao_code
# 25           2      A320
# Airbus
# 32X
#     nb_engines icao_code
# 26           2      A321
# Airbus
# 330
#     nb_engines icao_code
# 27         NaN       NaN
# Airbus
# 332
#     nb_engines icao_code
# 28           2      A332
# Airbus
# 333
#     nb_engines icao_code
# 29           2      A333
# Airbus
# 33F
#     nb_engines icao_code
# 30         NaN       NaN
# Airbus
# 33X
#     nb_engines icao_code
# 31           2      A332
# Airbus
# 340
#     nb_engines icao_code
# 32         NaN       NaN
# Airbus
# 342
#     nb_engines icao_code
# 33           4      A342
# Airbus
# 343
#     nb_engines icao_code
# 34           4      A343
# Airbus
# 345
#     nb_engines icao_code
# 35           4      A345
# Airbus
# 346
#     nb_engines icao_code
# 36           4      A346
# Airbus
# 350
#     nb_engines icao_code
# 37         NaN       NaN
# Airbus
# 351
#     nb_engines icao_code
# 38           2      ZZZZ
# Airbus
# 358
#     nb_engines icao_code
# 39           2      ZZZZ
# Airbus
# 359
#     nb_engines icao_code
# 40           2      ZZZZ
# Airbus
# 380
#     nb_engines icao_code
# 41         NaN       NaN
# Airbus
# 388
#     nb_engines icao_code
# 42           4      A388
# Airbus
# 38F
#     nb_engines icao_code
# 43           4      A388
# Airbus
# AB2
#      nb_engines icao_code
# 147         NaN       NaN
# Airbus
# AB3
#      nb_engines icao_code
# 148         NaN       NaN
# Airbus
# AB4
#      nb_engines icao_code
# 149           2      A30B
# Airbus
# AB6
#      nb_engines icao_code
# 150           2      A306
# Airbus
# ABB
#      nb_engines icao_code
# 151           2      A3ST
# Airbus
# ABF
#      nb_engines icao_code
# 152         NaN       NaN
# Airbus
# ABM
#      nb_engines icao_code
# 153         NaN       NaN
# Airbus
# ABX
#      nb_engines icao_code
# 154           2      A30B
# Airbus
# ABY
#      nb_engines icao_code
# 155           2      A306
# Aircraft Industries (LET)
# L4F
#      nb_engines icao_code
# 381           2      L410
# Airtech
# CS5
#      nb_engines icao_code
# 237           2      CN35
# Antonov
# A22
#      nb_engines icao_code
# 136           4      AN22
# Antonov
# A38
#      nb_engines icao_code
# 141           2      AN38
# Antonov
# A58
#      nb_engines icao_code
# 144           2      ZZZZ
# Antonov
# A5F
#      nb_engines icao_code
# 145           6      A225
# Antonov
# A81
#      nb_engines icao_code
# 146           2      A148
# Antonov
# AN2
#      nb_engines icao_code
# 162         NaN       NaN
# Antonow / Antonov
# A26
#      nb_engines icao_code
# 137           2      AN26
# Antonow / Antonov
# A28
#      nb_engines icao_code
# 138           2      AN28
# Antonow / Antonov
# A30
#      nb_engines icao_code
# 139           2      AN30
# Antonow / Antonov
# A32
#      nb_engines icao_code
# 140           2      AN32
# Antonow / Antonov
# A40
#      nb_engines icao_code
# 142           2      A140
# Antonow / Antonov
# A4F
#      nb_engines icao_code
# 143           4      A124
# Antonow / Antonov
# AN4
#      nb_engines icao_code
# 163           2      AN24
# Antonow / Antonov
# AN6
#      nb_engines icao_code
# 164         NaN       NaN
# Antonow / Antonov
# AN7
#      nb_engines icao_code
# 165           2      AN72
# Antonow / Antonov
# ANF
#      nb_engines icao_code
# 166           4      AN12
# Ayres
# ALM
#      nb_engines icao_code
# 160         NaN       NaN
# BAC
# B11
#      nb_engines icao_code
# 182         NaN       NaN
# BAC
# B12
#      nb_engines icao_code
# 183           2      BA11
# BAC
# B13
#      nb_engines icao_code
# 184           2      BA11
# BAC
# B14
#      nb_engines icao_code
# 185           2      BA11
# BAC
# B15
#      nb_engines icao_code
# 186           2      BA11
# BAe
# 141
#    nb_engines icao_code
# 1           4      B461
# BAe
# 142
#    nb_engines icao_code
# 2           4      B462
# BAe
# 143
#    nb_engines icao_code
# 3           4      B463
# BAe
# 146
#    nb_engines icao_code
# 4         NaN       NaN
# BAe
# 14F
#    nb_engines icao_code
# 5         NaN       NaN
# BAe
# 14X
#    nb_engines icao_code
# 6           4      B461
# BAe
# 14Y
#    nb_engines icao_code
# 7           4      B462
# BAe
# 14Z
#    nb_engines icao_code
# 8           4      B463
# BAe
# APF
#      nb_engines icao_code
# 167           2      ZZZZ
# BAe
# AR1
#      nb_engines icao_code
# 169           4      RJ1H
# BAe
# AR7
#      nb_engines icao_code
# 170           4      RJ70
# BAe
# AR8
#      nb_engines icao_code
# 171           4      RJ85
# BAe
# ARJ
#      nb_engines icao_code
# 172         NaN       NaN
# BAe
# ATP
#      nb_engines icao_code
# 178           2       ATP
# BAe
# HS7
#      nb_engines icao_code
# 359           2      A748
# BAe
# J31
#      nb_engines icao_code
# 371           2      JS31
# BAe
# J32
#      nb_engines icao_code
# 372           2      JS32
# BAe
# J41
#      nb_engines icao_code
# 373           2      JS41
# BAe
# JST
#      nb_engines icao_code
# 374         NaN       NaN
# Beechcraft
# BE1
#      nb_engines icao_code
# 188         NaN       NaN
# Beechcraft
# BE2
#      nb_engines icao_code
# 189           2         *
# Beechcraft
# BE4
#      nb_engines icao_code
# 190           2      BE40
# Beechcraft
# BE9
#      nb_engines icao_code
# 191           2      BE99
# Beechcraft
# BEC
#      nb_engines icao_code
# 192         NaN       NaN
# Beechcraft
# BEF
#      nb_engines icao_code
# 193           2      B190
# Beechcraft
# BEH
#      nb_engines icao_code
# 194           2      B190
# Beechcraft
# BEP
#      nb_engines icao_code
# 195           1         *
# Beechcraft
# BES
#      nb_engines icao_code
# 196           2      B190
# Beechcraft
# BET
#      nb_engines icao_code
# 197           2         *
# Bell Helicopter
# BH2
#      nb_engines icao_code
# 198         NaN         *
# Boeing
# 703
#     nb_engines icao_code
# 44           4      B703
# Boeing
# 707
#     nb_engines icao_code
# 45         NaN       NaN
# Boeing
# 70F
#     nb_engines icao_code
# 46           4      B703
# Boeing
# 70M
#     nb_engines icao_code
# 47           4      B703
# Boeing
# 717
#     nb_engines icao_code
# 48           2      B712
# Boeing
# 721
#     nb_engines icao_code
# 49           3      B721
# Boeing
# 722
#     nb_engines icao_code
# 50           3      B722
# Boeing
# 727
#     nb_engines icao_code
# 51         NaN       NaN
# Boeing
# 72A
#     nb_engines icao_code
# 52         NaN       NaN
# Boeing
# 72B
#     nb_engines icao_code
# 53           3      B721
# Boeing
# 72C
#     nb_engines icao_code
# 54           3      B722
# Boeing
# 72F
#     nb_engines icao_code
# 55         NaN       NaN
# Boeing
# 72M
#     nb_engines icao_code
# 56         NaN       NaN
# Boeing
# 72S
#     nb_engines icao_code
# 57         NaN       NaN
# Boeing
# 72W
#     nb_engines icao_code
# 58           3      B722
# Boeing
# 72X
#     nb_engines icao_code
# 59           3      B721
# Boeing
# 72Y
#     nb_engines icao_code
# 60           3      B722
# Boeing
# 731
#     nb_engines icao_code
# 61           2      B731
# Boeing
# 732
#     nb_engines icao_code
# 62           2      B732
# Boeing
# 733
#     nb_engines icao_code
# 63           2      B733
# Boeing
# 734
#     nb_engines icao_code
# 64           2      B734
# Boeing
# 735
#     nb_engines icao_code
# 65           2      B735
# Boeing
# 736
#     nb_engines icao_code
# 66           2      B736
# Boeing
# 737
#     nb_engines icao_code
# 67         NaN       NaN
# Boeing
# 738
#     nb_engines icao_code
# 68           2      B738
# Boeing
# 739
#     nb_engines icao_code
# 69           2      B739
# Boeing
# 73A
#     nb_engines icao_code
# 70         NaN       NaN
# Boeing
# 73C
#     nb_engines icao_code
# 71           2      B733
# Boeing
# 73E
#     nb_engines icao_code
# 72           2      B735
# Boeing
# 73F
#     nb_engines icao_code
# 73         NaN       NaN
# Boeing
# 73G
#     nb_engines icao_code
# 74           2      B737
# Boeing
# 73H
#     nb_engines icao_code
# 75           2      B738
# Boeing
# 73J
#     nb_engines icao_code
# 76           2      B739
# Boeing
# 73L
#     nb_engines icao_code
# 77           2      B732
# Boeing
# 73M
#     nb_engines icao_code
# 78         NaN       NaN
# Boeing
# 73N
#     nb_engines icao_code
# 79           2      B733
# Boeing
# 73P
#     nb_engines icao_code
# 80           2      B734
# Boeing
# 73Q
#     nb_engines icao_code
# 81           2      B734
# Boeing
# 73R
#     nb_engines icao_code
# 82           2      B737
# Boeing
# 73S
#     nb_engines icao_code
# 83           2      B737
# Boeing
# 73W
#     nb_engines icao_code
# 84           2      B737
# Boeing
# 73X
#     nb_engines icao_code
# 85           2      B732
# Boeing
# 73Y
#     nb_engines icao_code
# 86           2      B733
# Boeing
# 73Z
#     nb_engines icao_code
# 87         NaN       NaN
# Boeing
# 741
#     nb_engines icao_code
# 88           4      B741
# Boeing
# 742
#     nb_engines icao_code
# 89           4      B742
# Boeing
# 743
#     nb_engines icao_code
# 90           4      B743
# Boeing
# 744
#     nb_engines icao_code
# 91           4      B744
# Boeing
# 747
#     nb_engines icao_code
# 92         NaN       NaN
# Boeing
# 74B
#     nb_engines icao_code
# 93           4      B744
# Boeing
# 74C
#     nb_engines icao_code
# 94           4      B742
# Boeing
# 74D
#     nb_engines icao_code
# 95           4      B743
# Boeing
# 74E
#     nb_engines icao_code
# 96           4      B744
# Boeing
# 74F
#     nb_engines icao_code
# 97         NaN       NaN
# Boeing
# 74H
#     nb_engines icao_code
# 98           4      B748
# Boeing
# 74J
#     nb_engines icao_code
# 99           4      B74D
# Boeing
# 74L
#      nb_engines icao_code
# 100           4      B74S
# Boeing
# 74M
#      nb_engines icao_code
# 101         NaN       NaN
# Boeing
# 74N
#      nb_engines icao_code
# 102           4      B748
# Boeing
# 74R
#      nb_engines icao_code
# 103           4      B74R
# Boeing
# 74T
#      nb_engines icao_code
# 104           4      B741
# Boeing
# 74U
#      nb_engines icao_code
# 105           4      B743
# Boeing
# 74V
#      nb_engines icao_code
# 106           4      B74R
# Boeing
# 74X
#      nb_engines icao_code
# 107           4      B742
# Boeing
# 74Y
#      nb_engines icao_code
# 108           4      B744
# Boeing
# 752
#      nb_engines icao_code
# 109           2      B752
# Boeing
# 753
#      nb_engines icao_code
# 110           2      B753
# Boeing
# 757
#      nb_engines icao_code
# 111         NaN       NaN
# Boeing
# 75F
#      nb_engines icao_code
# 112           2      B752
# Boeing
# 75M
#      nb_engines icao_code
# 113           2      B752
# Boeing
# 75T
#      nb_engines icao_code
# 114           2      B753
# Boeing
# 75W
#      nb_engines icao_code
# 115           2      B752
# Boeing
# 762
#      nb_engines icao_code
# 116           2      B762
# Boeing
# 763
#      nb_engines icao_code
# 117           2      B763
# Boeing
# 764
#      nb_engines icao_code
# 118           2      B764
# Boeing
# 767
#      nb_engines icao_code
# 119         NaN       NaN
# Boeing
# 76F
#      nb_engines icao_code
# 120         NaN       NaN
# Boeing
# 76V
#      nb_engines icao_code
# 121           2      B763
# Boeing
# 76W
#      nb_engines icao_code
# 122           2      B763
# Boeing
# 76X
#      nb_engines icao_code
# 123           2      B762
# Boeing
# 76Y
#      nb_engines icao_code
# 124           2      B763
# Boeing
# 772
#      nb_engines icao_code
# 125           2      B77L
# Boeing
# 773
#      nb_engines icao_code
# 126           2      B773
# Boeing
# 777
#      nb_engines icao_code
# 127         NaN       NaN
# Boeing
# 77F
#      nb_engines icao_code
# 128         NaN       NaN
# Boeing
# 77L
#      nb_engines icao_code
# 129           2      B772
# Boeing
# 77W
#      nb_engines icao_code
# 130           2      B77W
# Boeing
# 77X
#      nb_engines icao_code
# 131           2      B772
# Boeing
# 783
#      nb_engines icao_code
# 132           2      B783
# Boeing
# 787
#      nb_engines icao_code
# 133         NaN       NaN
# Boeing
# 788
#      nb_engines icao_code
# 134           2      B788
# Boeing
# 789
#      nb_engines icao_code
# 135           2      B789
# Boeing
# B72
#      nb_engines icao_code
# 187           4      B720
# Bombardier
# CCX
#      nb_engines icao_code
# 206           2      GLEX
# Bombardier
# CL3
#      nb_engines icao_code
# 215           2      CL30
# Bombardier
# CS1
#      nb_engines icao_code
# 234           2      ZZZZ
# Bombardier
# CS3
#      nb_engines icao_code
# 236           2      ZZZZ
# Britten Norman
# BNI
#      nb_engines icao_code
# 199           2      BN2P
# Britten Norman
# BNT
#      nb_engines icao_code
# 200           3      TRIS
# CASA
# CS2
#      nb_engines icao_code
# 235           2      C212
# Canadair
# C9B
#      nb_engines icao_code
# 204         NaN       NaN
# Canadair
# CCJ
#      nb_engines icao_code
# 205           2      CL60
# Canadair
# CL4
#      nb_engines icao_code
# 216         NaN       NaN
# Canadair
# CR1
#      nb_engines icao_code
# 225           2      CRJ1
# Canadair
# CR2
#      nb_engines icao_code
# 226           2      CRJ2
# Canadair
# CR7
#      nb_engines icao_code
# 227           2      CRJ7
# Canadair
# CR9
#      nb_engines icao_code
# 228           2      CRJ9
# Canadair
# CRA
#      nb_engines icao_code
# 229           2      CRJ9
# Canadair
# CRF
#      nb_engines icao_code
# 230           2      ZZZZ
# Canadair
# CRJ
#      nb_engines icao_code
# 231         NaN       NaN
# Canadair
# CRK
#      nb_engines icao_code
# 232           2      CRJX
# Cessna
# CJ1
#      nb_engines icao_code
# 208           2         *
# Cessna
# CJ2
#      nb_engines icao_code
# 209           2         *
# Cessna
# CJ5
#      nb_engines icao_code
# 210           2         *
# Cessna
# CJ6
#      nb_engines icao_code
# 211           2         *
# Cessna
# CJ8
#      nb_engines icao_code
# 212           2         *
# Cessna
# CJL
#      nb_engines icao_code
# 213           2         *
# Cessna
# CJM
#      nb_engines icao_code
# 214           2      C510
# Cessna
# CN1
#      nb_engines icao_code
# 217           1         *
# Cessna
# CN2
#      nb_engines icao_code
# 218           2         *
# Cessna
# CN7
#      nb_engines icao_code
# 219           2      C750
# Cessna
# CNA
#      nb_engines icao_code
# 220         NaN       NaN
# Cessna
# CNC
#      nb_engines icao_code
# 221           1         *
# Cessna
# CNF
#      nb_engines icao_code
# 222           2         *
# Cessna
# CNJ
#      nb_engines icao_code
# 223           2         *
# Cessna
# CNT
#      nb_engines icao_code
# 224           2         *
# Comac
# C27
#      nb_engines icao_code
# 203           2      AJ27
# Convair
# CV2
#      nb_engines icao_code
# 238           2      CVLP
# Convair
# CV4
#      nb_engines icao_code
# 239           2      CVLP
# Convair
# CV5
#      nb_engines icao_code
# 240           2      CVLT
# Convair
# CV6
#      nb_engines icao_code
# 241         NaN       NaN
# Convair
# CVF
#      nb_engines icao_code
# 242         NaN       NaN
# Convair
# CVR
#      nb_engines icao_code
# 243         NaN       NaN
# Convair
# CVV
#      nb_engines icao_code
# 244           2      CVLP
# Convair
# CVX
#      nb_engines icao_code
# 245           2      CVLP
# Convair
# CVY
#      nb_engines icao_code
# 246           2      CVLT
# Curtiss
# CWC
#      nb_engines icao_code
# 247           2       C46
# DAHER-SOCATA
# TBM
#      nb_engines icao_code
# 445           1      TBM7
# Dassault
# AMD
#      nb_engines icao_code
# 161         NaN       NaN
# Dassault
# D20
#      nb_engines icao_code
# 256           2      F2TH
# Dassault
# D2L
#      nb_engines icao_code
# 258           2      F2TH
# Dassault
# D9L
#      nb_engines icao_code
# 284           3      F900
# Dassault
# DF1
#      nb_engines icao_code
# 291           2      FA10
# Dassault
# DF2
#      nb_engines icao_code
# 292           2      FA20
# Dassault
# DF3
#      nb_engines icao_code
# 293         NaN       NaN
# Dassault
# DF5
#      nb_engines icao_code
# 294           3      FA50
# Dassault
# DF7
#      nb_engines icao_code
# 295           3      FA7X
# Dassault
# DF9
#      nb_engines icao_code
# 296           3      F900
# Dassault
# DFL
#      nb_engines icao_code
# 297         NaN       NaN
# De Havilland
# DHD
#      nb_engines icao_code
# 306           2      DOVE
# De Havilland
# DHH
#      nb_engines icao_code
# 308           4      HERN
# De Havilland Canada
# DH7
#      nb_engines icao_code
# 302           4      DHC7
# De Havilland Canada
# DHB
#      nb_engines icao_code
# 304         NaN       NaN
# De Havilland Canada
# DHC
#      nb_engines icao_code
# 305           2      DHC4
# De Havilland Canada
# DHL
#      nb_engines icao_code
# 309           1      DH3T
# De Havilland Canada
# DHO
#      nb_engines icao_code
# 310         NaN       NaN
# De Havilland Canada
# DHP
#      nb_engines icao_code
# 311           1      DHC2
# De Havilland Canada
# DHR
#      nb_engines icao_code
# 312           1      DH2T
# De Havilland Canada
# DHS
#      nb_engines icao_code
# 313           1      DHC3
# De Havilland Canada
# DHT
#      nb_engines icao_code
# 314         NaN        2T
# De Havilland Canada-Bombardier
# D4X
#      nb_engines icao_code
# 262           2      DH8D
# De Havilland Canada-Bombardier
# DH1
#      nb_engines icao_code
# 298           2      DH8A
# De Havilland Canada-Bombardier
# DH2
#      nb_engines icao_code
# 299           2      DH8B
# De Havilland Canada-Bombardier
# DH3
#      nb_engines icao_code
# 300           2      DH8C
# De Havilland Canada-Bombardier
# DH4
#      nb_engines icao_code
# 301           2      DH8D
# De Havilland Canada-Bombardier
# DH8
#      nb_engines icao_code
# 303         NaN       NaN
# De Havilland-Bombardier
# DHF
#      nb_engines icao_code
# 307         NaN      0000
# Diamond Aircraft
# D42
#      nb_engines icao_code
# 261           2      DA42
# Dornier
# D28
#      nb_engines icao_code
# 257           2      D228
# Dornier
# D38
#      nb_engines icao_code
# 259           2      D328
# Dornier
# FR3
#      nb_engines icao_code
# 340         NaN       NaN
# Dornier
# FR4
#      nb_engines icao_code
# 341         NaN       NaN
# Dornier
# FRJ
#      nb_engines icao_code
# 342           2      J328
# Douglas
# D3F
#      nb_engines icao_code
# 260           2       DC3
# Douglas
# D6F
#      nb_engines icao_code
# 263           4       DC6
# Douglas
# D85
#      nb_engines icao_code
# 264         NaN       NaN
# Douglas
# D86
#      nb_engines icao_code
# 265         NaN       NaN
# Douglas
# D87
#      nb_engines icao_code
# 266         NaN       NaN
# Douglas
# D8A
#      nb_engines icao_code
# 267         NaN       NaN
# Douglas
# D8B
#      nb_engines icao_code
# 268         NaN       NaN
# Douglas
# D8F
#      nb_engines icao_code
# 269         NaN       NaN
# Douglas
# D8L
#      nb_engines icao_code
# 270           4      DC86
# Douglas
# D8M
#      nb_engines icao_code
# 271           4      DC86
# Douglas
# D8Q
#      nb_engines icao_code
# 272           4      DC87
# Douglas
# D8T
#      nb_engines icao_code
# 273           4      DC85
# Douglas
# D8X
#      nb_engines icao_code
# 274           4      DC86
# Douglas
# D8Y
#      nb_engines icao_code
# 275           4      DC87
# Douglas
# D91
#      nb_engines icao_code
# 276           2      DC91
# Douglas
# D92
#      nb_engines icao_code
# 277           2      DC92
# Douglas
# D93
#      nb_engines icao_code
# 278           2      DC93
# Douglas
# D94
#      nb_engines icao_code
# 279           2      DC94
# Douglas
# D95
#      nb_engines icao_code
# 280           2      DC95
# Douglas
# D9C
#      nb_engines icao_code
# 281           2      DC93
# Douglas
# D9D
#      nb_engines icao_code
# 282           2      DC94
# Douglas
# D9F
#      nb_engines icao_code
# 283         NaN       NaN
# Douglas
# D9X
#      nb_engines icao_code
# 285           2      DC91
# Douglas
# DC3
#      nb_engines icao_code
# 286           2       DC3
# Douglas
# DC4
#      nb_engines icao_code
# 287           4       DC4
# Douglas
# DC6
#      nb_engines icao_code
# 288           4       DC6
# Douglas
# DC8
#      nb_engines icao_code
# 289         NaN       NaN
# Douglas
# DC9
#      nb_engines icao_code
# 290         NaN       NaN
# Eclipse
# EA5
#      nb_engines icao_code
# 319           2      EA50
# Embraer
# E70
#      nb_engines icao_code
# 315           2      E170
# Embraer
# E75
#      nb_engines icao_code
# 316           2      E170
# Embraer
# E90
#      nb_engines icao_code
# 317           2      E190
# Embraer
# E95
#      nb_engines icao_code
# 318           2      E190
# Embraer
# EM2
#      nb_engines icao_code
# 321           2      E120
# Embraer
# EMB
#      nb_engines icao_code
# 322           2      E110
# Embraer
# EMJ
#      nb_engines icao_code
# 323         NaN       NaN
# Embraer
# EP1
#      nb_engines icao_code
# 324           2      E50P
# Embraer
# EP3
#      nb_engines icao_code
# 325           2      E55P
# Embraer
# ER3
#      nb_engines icao_code
# 326           2      E135
# Embraer
# ER4
#      nb_engines icao_code
# 327           2      E145
# Embraer
# ERD
#      nb_engines icao_code
# 328           2      E135
# Embraer
# ERJ
#      nb_engines icao_code
# 329         NaN       NaN
# Eurocopter
# APH
#      nb_engines icao_code
# 168         NaN         *
# Eurocopter
# EC3
#      nb_engines icao_code
# 320         NaN      EC30
# Eurocopter
# NDE
#      nb_engines icao_code
# 412         NaN         *
# Eurocopter
# NDH
#      nb_engines icao_code
# 413         NaN         *
# Fairchild-Hiller
# FK7
#      nb_engines icao_code
# 339           2       F27
# Fairchild-Swearingen
# SWF
#      nb_engines icao_code
# 439           2         *
# Fairchild-Swearingen
# SWM
#      nb_engines icao_code
# 440           2         *
# Fokker
# 100
#    nb_engines icao_code
# 0           2      F100
# Fokker
# F21
#      nb_engines icao_code
# 330           2       F28
# Fokker
# F22
#      nb_engines icao_code
# 331           2       F28
# Fokker
# F23
#      nb_engines icao_code
# 332           2       F28
# Fokker
# F24
#      nb_engines icao_code
# 333           2       F28
# Fokker
# F27
#      nb_engines icao_code
# 334           2       F27
# Fokker
# F28
#      nb_engines icao_code
# 335         NaN       NaN
# Fokker
# F50
#      nb_engines icao_code
# 336           2       F50
# Fokker
# F5F
#      nb_engines icao_code
# 337           2       F50
# Fokker
# F70
#      nb_engines icao_code
# 338           2       F70
# GAF
# CD2
#      nb_engines icao_code
# 207           2      NOMA
# GippsAero
# GA8
#      nb_engines icao_code
# 343           1       GA8
# Grumman
# GRG
#      nb_engines icao_code
# 347           2       G21
# Gulfstream
# GR1
#      nb_engines icao_code
# 344           2      G150
# Gulfstream
# GR2
#      nb_engines icao_code
# 345           2      GALX
# Gulfstream
# GR3
#      nb_engines icao_code
# 346           2      G250
# Gulfstream
# GRJ
#      nb_engines icao_code
# 348           2         *
# Gulfstream
# GRM
#      nb_engines icao_code
# 349           2      G73T
# Gulfstream
# GRS
#      nb_engines icao_code
# 350           2      G159
# HAMC / Harbin
# YN2
#      nb_engines icao_code
# 454           2       Y12
# Hawker-Beechcraft
# H20
#      nb_engines icao_code
# 351           2      ZZZZ
# Hawker-Beechcraft
# H21
#      nb_engines icao_code
# 352           2      H25C
# Hawker-Beechcraft
# H24
#      nb_engines icao_code
# 353           2      HA4T
# Hawker-Beechcraft
# H28
#      nb_engines icao_code
# 355           2      H25B
# Hawker-Beechcraft
# H29
#      nb_engines icao_code
# 356           2      H25B
# Hawker-Beechcraft
# PRI
#      nb_engines icao_code
# 422           2      PRM1
# Hawker-Siddeley
# H25
#      nb_engines icao_code
# 354           2      H25B
# Helio
# HEC
#      nb_engines icao_code
# 357           1      COUR
# IAI
# WWP
#      nb_engines icao_code
# 451           2      WW24
# Ilyushin
# I14
#      nb_engines icao_code
# 360           2      I114
# Ilyushin
# I93
#      nb_engines icao_code
# 361         NaN       NaN
# Ilyushin
# I9F
#      nb_engines icao_code
# 362           4      IL96
# Ilyushin
# I9M
#      nb_engines icao_code
# 363         NaN       NaN
# Ilyushin
# I9X
#      nb_engines icao_code
# 364         NaN       NaN
# Ilyushin
# I9Y
#      nb_engines icao_code
# 365         NaN       NaN
# Ilyushin
# IL6
#      nb_engines icao_code
# 366           4      IL62
# Ilyushin
# IL7
#      nb_engines icao_code
# 367           4      IL76
# Ilyushin
# IL8
#      nb_engines icao_code
# 368           4      IL18
# Ilyushin
# IL9
#      nb_engines icao_code
# 369           4      IL96
# Ilyushin
# ILW
#      nb_engines icao_code
# 370           4      IL86
# Junkers
# JU5
#      nb_engines icao_code
# 375           3      JU52
# LET
# L4T
#      nb_engines icao_code
# 382           2      L410
# Learjet
# LRJ
#      nb_engines icao_code
# 390           2         *
# Lockheed
# L10
#      nb_engines icao_code
# 376         NaN       NaN
# Lockheed
# L11
#      nb_engines icao_code
# 377           3      L101
# Lockheed
# L15
#      nb_engines icao_code
# 378           3      L101
# Lockheed
# L1F
#      nb_engines icao_code
# 379           3      L101
# Lockheed
# L49
#      nb_engines icao_code
# 380         NaN       NaN
# Lockheed
# LOE
#      nb_engines icao_code
# 386           4      L188
# Lockheed
# LOF
#      nb_engines icao_code
# 387           4      L188
# Lockheed
# LOH
#      nb_engines icao_code
# 388           4      C130
# Lockheed
# LOM
#      nb_engines icao_code
# 389         NaN       NaN
# MBB
# MBH
#      nb_engines icao_code
# 406         NaN      B105
# MD Helicopters
# MD9
#      nb_engines icao_code
# 407         NaN      EXPL
# McDonnell Douglas
# D10
#      nb_engines icao_code
# 248         NaN       NaN
# McDonnell Douglas
# D11
#      nb_engines icao_code
# 249           3      DC10
# McDonnell Douglas
# D14
#      nb_engines icao_code
# 250         NaN       NaN
# McDonnell Douglas
# D1C
#      nb_engines icao_code
# 251           3      DC10
# McDonnell Douglas
# D1F
#      nb_engines icao_code
# 252         NaN       NaN
# McDonnell Douglas
# D1M
#      nb_engines icao_code
# 253           3      DC10
# McDonnell Douglas
# D1X
#      nb_engines icao_code
# 254           3      DC10
# McDonnell Douglas
# D1Y
#      nb_engines icao_code
# 255           3      DC10
# McDonnell Douglas
# M11
#      nb_engines icao_code
# 391           3      MD11
# McDonnell Douglas
# M1F
#      nb_engines icao_code
# 392           3      MD11
# McDonnell Douglas
# M1M
#      nb_engines icao_code
# 393           3      MD11
# McDonnell Douglas
# M2F
#      nb_engines icao_code
# 394           2      MD82
# McDonnell Douglas
# M3F
#      nb_engines icao_code
# 395           2      MD83
# McDonnell Douglas
# M80
#      nb_engines icao_code
# 396         NaN       NaN
# McDonnell Douglas
# M81
#      nb_engines icao_code
# 397           2      MD81
# McDonnell Douglas
# M82
#      nb_engines icao_code
# 398           2      MD82
# McDonnell Douglas
# M83
#      nb_engines icao_code
# 399           2      MD83
# McDonnell Douglas
# M87
#      nb_engines icao_code
# 400           2      MD87
# McDonnell Douglas
# M88
#      nb_engines icao_code
# 401           2      MD88
# McDonnell Douglas
# M8F
#      nb_engines icao_code
# 402           2      MD88
# McDonnell Douglas
# M90
#      nb_engines icao_code
# 403           2      MD90
# McDonnell Douglas
# M95
#      nb_engines icao_code
# 404         NaN       NaN
# Mil
# MIH
#      nb_engines icao_code
# 408         NaN       MI8
# Mitsubishi
# MU2
#      nb_engines icao_code
# 409           2       MU2
# NAMC
# YS1
#      nb_engines icao_code
# 456           2      YS11
# Nord / SNCAN
# ND2
#      nb_engines icao_code
# 410         NaN       NaN
# Partenavia
# PN6
#      nb_engines icao_code
# 421           2       P68
# Piaggio Aero
# P18
#      nb_engines icao_code
# 414           2      P180
# Pilatus
# PL2
#      nb_engines icao_code
# 419           1      PC12
# Pilatus
# PL6
#      nb_engines icao_code
# 420           1      PC6T
# Piper
# PA1
#      nb_engines icao_code
# 415           1         *
# Piper
# PA2
#      nb_engines icao_code
# 416           2         *
# Piper
# PAG
#      nb_engines icao_code
# 417         NaN       NaN
# Piper
# PAT
#      nb_engines icao_code
# 418           2         *
# Rockwell
# ACD
#      nb_engines icao_code
# 156         NaN       NaN
# Rockwell
# ACP
#      nb_engines icao_code
# 157           2         *
# Rockwell
# ACT
#      nb_engines icao_code
# 158           2         *
# Saab
# S20
#      nb_engines icao_code
# 424           2      SB20
# Saab
# SF3
#      nb_engines icao_code
# 428           2      SF34
# Saab
# SFB
#      nb_engines icao_code
# 429           2      SF34
# Saab
# SFF
#      nb_engines icao_code
# 430           2      SF34
# Shaanxi
# SY8
#      nb_engines icao_code
# 441           4      AN12
# Shorts
# SH3
#      nb_engines icao_code
# 431           2      SH33
# Shorts
# SH6
#      nb_engines icao_code
# 432           2      SH36
# Shorts
# SHB
#      nb_engines icao_code
# 433         NaN       NaN
# Shorts
# SHS
#      nb_engines icao_code
# 434           2       SC7
# Sikorsky
# S58
#      nb_engines icao_code
# 425         NaN      S58T
# Sikorsky
# S61
#      nb_engines icao_code
# 426         NaN       S61
# Sikorsky
# S76
#      nb_engines icao_code
# 427         NaN       S76
# Sud-Est
# CRV
#      nb_engines icao_code
# 233         NaN       NaN
# Sukhoi
# SU1
#      nb_engines icao_code
# 436         NaN       NaN
# Sukhoi
# SU7
#      nb_engines icao_code
# 437           2      ZZZZ
# Sukhoi
# SU9
#      nb_engines icao_code
# 438           2      SU95
# Surface Equipment
# BUS
#      nb_engines icao_code
# 202         NaN      0000
# Surface Equipment
# LCH
#      nb_engines icao_code
# 383         NaN      0000
# Surface Equipment
# LMO
#      nb_engines icao_code
# 385         NaN      0000
# Surface Equipment
# TRN
#      nb_engines icao_code
# 446         NaN      0000
# Tupolev
# T20
#      nb_engines icao_code
# 442           2      T204
# Tupolev
# T2F
#      nb_engines icao_code
# 443           2      T204
# Tupolev
# T34
#      nb_engines icao_code
# 444           2      T334
# Tupolev
# TU3
#      nb_engines icao_code
# 447           2      T134
# Tupolev
# TU5
#      nb_engines icao_code
# 448           3      T154
# Vickers
# VCV
#      nb_engines icao_code
# 449         NaN       NaN
# Vickers
# VCX
#      nb_engines icao_code
# 450         NaN       NaN
# Xian
# MA6
#      nb_engines icao_code
# 405           2      AN24
# Xian
# YN7
#      nb_engines icao_code
# 455           2      AN24
# Yakovlev / Jakovlev
# YK2
#      nb_engines icao_code
# 452           3      YK42
# Yakovlev / Jakovlev
# YK4
#      nb_engines icao_code
# 453           3      YK40

# %%
gb.aggregate(['mean','std'])
# Out:
#                                nb_engines
#                                      mean       std
# manufacturer
# ATR                              2.000000  0.000000
# Aerospatiale / SNIAS             2.000000       NaN
# Agusta / AgustaWestland               NaN       NaN
# AgustaWestland                   2.000000       NaN
# Airbus                           2.413793  0.824502
# Aircraft Industries (LET)        2.000000       NaN
# Airtech                          2.000000       NaN
# Antonov                          3.200000  1.788854
# Antonow / Antonov                2.444444  0.881917
# Ayres                                 NaN       NaN
# BAC                              2.000000  0.000000
# BAe                              3.200000  1.014185
# Beechcraft                       1.875000  0.353553
# Bell Helicopter                       NaN       NaN
# Boeing                           2.698630  0.908065
# Bombardier                       2.000000  0.000000
# Britten Norman                   2.500000  0.707107
# CASA                             2.000000       NaN
# Canadair                         2.000000  0.000000
# Cessna                           1.857143  0.363137
# Comac                            2.000000       NaN
# Convair                          2.000000  0.000000
# Curtiss                          2.000000       NaN
# DAHER-SOCATA                     1.000000       NaN
# Dassault                         2.500000  0.534522
# De Havilland                     3.000000  1.414214
# De Havilland Canada              1.666667  1.211060
# De Havilland Canada-Bombardier   2.000000  0.000000
# De Havilland-Bombardier               NaN       NaN
# Diamond Aircraft                 2.000000       NaN
# ...                                   ...       ...
# Helio                            1.000000       NaN
# IAI                              2.000000       NaN
# Ilyushin                         3.714286  0.755929
# Junkers                          3.000000       NaN
# LET                              2.000000       NaN
# Learjet                          2.000000       NaN
# Lockheed                         3.500000  0.547723
# MBB                                   NaN       NaN
# MD Helicopters                        NaN       NaN
# McDonnell Douglas                2.470588  0.514496
# Mil                                   NaN       NaN
# Mitsubishi                       2.000000       NaN
# NAMC                             2.000000       NaN
# Nord / SNCAN                          NaN       NaN
# Partenavia                       2.000000       NaN
# Piaggio Aero                     2.000000       NaN
# Pilatus                          1.000000  0.000000
# Piper                            1.666667  0.577350
# Rockwell                         2.000000  0.000000
# Saab                             2.000000  0.000000
# Shaanxi                          4.000000       NaN
# Shorts                           2.000000  0.000000
# Sikorsky                              NaN       NaN
# Sud-Est                               NaN       NaN
# Sukhoi                           2.000000  0.000000
# Surface Equipment                     NaN       NaN
# Tupolev                          2.200000  0.447214
# Vickers                               NaN       NaN
# Xian                             2.000000  0.000000
# Yakovlev / Jakovlev              3.000000  0.000000
#
# [75 rows x 2 columns]

# %% [markdown]
# ## Plotting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
mu, sigma = 100, 15

x = mu + sigma * np.random.randn(10000)

# %%
plt.hist(x, 50,normed =1)

plt.xlabel('IQ')
plt.ylabel('%')
plt.axis([40, 160, 0, 0.04])

plt.show()

# %%
plt.hist(x, 50)

plt.xlabel('IQ')
plt.ylabel('%')
plt.show()

# %%
plt.scatter(x, 1/x, alpha=0.1)

# %%
import seaborn as sns

# %%
x = np.linspace(0,100, 10000)

# %%
y = np.exp(x)

# %%
plt.plot(x,y)
