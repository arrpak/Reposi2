# %%
ls
# Out:
# 11b039f398ddcae88139/     enumerate.ipynb           Public/
# 20lines.txt               Finn.txt                  query
# 20lines.txt~wewew         funcion_centenario.ipynb  R/
# anaconda2/                hello.py                  Repositories/
# col4.txt                  hello.pyc                 Templates/
# comandos_20160319_2.txt   hist3.txt                 tuplas.ipynb
# comandos 20160319.txt     hist.txt                  Untitled1.ipynb
# Data/                     hola.py                   Untitled-Copy1.ipynb
# Desktop/                  macro.py                  Untitled.ipynb
# Documents/                metastore_db/             untitled.txt
# Downloads/                Music/                    Videos/
# ejemploficheros.ipynb     new_file                  wc
# ejemplo jupiter.py.ipynb  nuevodir/
# ejemplo_map_lambda.ipynb  Pictures/

# %%
lines = !wc -l /home/dsc/Finn.txt

# %%
type(lines)
# Out:
# IPython.utils.text.SList

# %%
finn_og_lines = int(numer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-bb40cc98283b> in <module>()
# ----> 1 finn_og_lines = int(numer)
#
# NameError: name 'numer' is not defined

# %%
f=open('Finn.txt')

# %%
lines_clean=[]
for line in f.readlines():
    my_line = line.rstrip()
    lines_clean.append(my_line)

# %%
lines_clean
# Out:
# ['\xef\xbb\xbf',
#  '',
#  'The Project Gutenberg EBook of Adventures of Huckleberry Finn, Complete',
#  'by Mark Twain (Samuel Clemens)',
#  '',
#  'This eBook is for the use of anyone anywhere at no cost and with almost',
#  'no restrictions whatsoever. You may copy it, give it away or re-use',
#  'it under the terms of the Project Gutenberg License included with this',
#  'eBook or online at www.gutenberg.net',
#  '',
#  'Title: Adventures of Huckleberry Finn, Complete',
#  '',
#  'Author: Mark Twain (Samuel Clemens)',
#  '',
#  'Release Date: August 20, 2006 [EBook #76]',
#  '',
#  'Last Updated: April 18, 2015]',
#  '',
#  'Language: English',
#  '',
#  '',
#  '*** START OF THIS PROJECT GUTENBERG EBOOK HUCKLEBERRY FINN ***',
#  '',
#  'Produced by David Widger',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ADVENTURES',
#  '',
#  'OF',
#  '',
#  'HUCKLEBERRY FINN',
#  '',
#  "(Tom Sawyer's Comrade)",
#  '',
#  'By Mark Twain',
#  '',
#  'Complete',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
f2 = open('Finn_clean.txt','w')

# %%
f2.writelines(lines_clean)

# %%
f.close()
f2.close()

# %%
finn_lines = !wc -l Finn.txt

# %%
finn_clean_lines = !wc -l Finn_clean.txt

# %%
finn_clean_lines
# Out:
# ['0 Finn_clean.txt']

# %%
names = ['Luis','Daniel','Isra','Sebas','Juan']

# %%
def capitalize_weird(word):
    lows = word.lower()
    vowels = 'aeiou'
    result = ''
    
    for l in lows:
        if l in vowels:
            result =result + l.upper()
        else:
            result = result + l
    return result

# %%
capitalize_weird('BarCenas')
# Out:
# 'bArcEnAs'

# %%
map(capitalize_weird,names)
# Out:
# ['lUIs', 'dAnIEl', 'IsrA', 'sEbAs', 'jUAn']

# %%
[capitalize_weird(word) for word in names ]
# Out:
# ['lUIs', 'dAnIEl', 'IsrA', 'sEbAs', 'jUAn']

# %%
[capitalize_weird(word) for word in names if len(word) > 4]
# Out:
# ['dAnIEl', 'sEbAs']

# %%
filter(lambda x: len(x)>4,names)
# Out:
# ['Daniel', 'Sebas']

# %%
map(capitalize_weird,filter(lambda x: len(x)>4,names))
# Out:
# ['dAnIEl', 'sEbAs']

# %%
#####
